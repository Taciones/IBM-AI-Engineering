# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/qo20b88v1hbjztubt06609ovs85q8fau.png" width="400px"  align="center"></a>
# <h1 align="center"><font size="5">LOGISTIC REGRESSION WITH TENSORFLOW</font></h1>

# %% [markdown]
# ## Table of Contents
#
# Logistic Regression is one of most important techniques in data science. It is usually used to solve the classic classification problem.
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size = 3><strong>This lesson covers the following concepts of Logistics Regression:</strong></font>
# <br>
# <h2>Table of Contents</h2>
#
# <ol>
#     <li><a href="#ref1">Linear Regression vs Logistic Regression</a></li>
#     <li><a href="#ref2">Utilizing Logistic Regression in TensorFlow</a></li>
#     <li><a href="#ref3">Training</a></li>
# </ol>
# </div>
# <p></p>
# <br>
#
# <hr>

# %% [markdown]
# <a id="ref1"></a>
# <h2>What is different between Linear and Logistic Regression?</h2>
#
# While Linear Regression is suited for estimating continuous values (e.g. estimating house price), it is n0t the best tool for predicting the class in which an observed data point belongs. In order to provide estimate for classification, we need some sort of guidance on what would be the <b>most probable class</b> for that data point. For this, we use <b>Logistic Regression</b>.
#
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# <font size="3"><strong>Recall linear regression:</strong></font>
# <br>
# <br>
# Linear regression finds a function that relates a continuous dependent variable, <i>y</i>, to some predictors (independent variables <i>x1</i>, <i>x2</i>, etc.). Simple linear regression assumes a function of the form:
# <br><br>
# $$
# y = w0 + w1 \times x1 + w2 \times x2 + \cdots
# $$
# <br>
# and finds the values of <i>w0</i>, <i>w1</i>, <i>w2</i>, etc. The term <i>w0</i> is the "intercept" or "constant term" (it's shown as <i>b</i> in the formula below):
# <br><br>
# $$
# Y = W X + b
# $$
# <p></p>
#
# </div>
#
# Logistic Regression is a variation of Linear Regression, useful when the observed dependent variable, <i>y</i>, is categorical. It produces a formula that predicts the probability of the class label as a function of the independent variables.
#
# Despite the name logistic <i>regression</i>, it is actually a <b>probabilistic classification</b> model. Logistic regression fits a special s-shaped curve by taking the linear regression and transforming the numeric estimate into a probability with the following function:
#
# $$
# ProbabilityOfaClass = \theta(y) = \frac{e^y}{1 + e^y} = exp(y) / (1 + exp(y)) = p
# $$
#
# which produces p-values between 0 (as y approaches minus infinity $-\infty$) and 1 (as y approaches plus infinity $+\infty$). This now becomes a special kind of non-linear regression.
#
# In this equation, <i>y</i> is the regression result (the sum of the variables weighted by the coefficients), <code>exp</code> is the exponential function and $\theta(y)$ is the <a href="http://en.wikipedia.org/wiki/Logistic_function">logistic function</a>, also called logistic curve. It is a common "S" shape (sigmoid curve), and was first developed for modeling population growth.
#
# You might also have seen this function before, in another configuration:
#
# $$
# ProbabilityOfaClass = \theta(y) = \frac{1}{1+e^{-y}}
# $$
#
# So, briefly, Logistic Regression passes the input through the logistic/sigmoid function but then treats the result as a probability:
#
# <img src="https://ibm.box.com/shared/static/kgv9alcghmjcv97op4d6onkyxevk23b1.png" width="400" align="center">

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a id="ref2"></a>
# <h2>Utilizing Logistic Regression in TensorFlow</h2>
#
# For us to utilize Logistic Regression in TensorFlow, we first need to import the required libraries. To do so, you can run the code cell below.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import time
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we will load the dataset we are going to use. In this case, we are utilizing the <code>iris</code> dataset, which is inbuilt -- so there's no need to do any preprocessing and we can jump right into manipulating it. We separate the dataset into <i>xs</i> and <i>ys</i>, and then into training <i>xs</i> and <i>ys</i> and testing <i>xs</i> and <i>ys</i>, (pseudo)randomly.

# %% [markdown]
# <h3>Understanding the Data</h3>
#
# <h4><code>Iris Dataset</code>:</h4>
# This dataset was introduced by British Statistician and Biologist Ronald Fisher, it consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). In total it has 150 records under five attributes - petal length, petal width, sepal length, sepal width and species. <a href="https://archive.ics.uci.edu/ml/datasets/iris">Dataset source</a>
#
# Attributes
# Independent Variable
# <ul>
#     <li>petal length</li>
#     <li>petal width</li>
#     <li>sepal length</li>
#     <li>sepal width</li>
# </ul>
# Dependent Variable
# <ul>
#     <li>Species
#         <ul>
#             <li>Iris setosa</li>
#             <li>Iris virginica</li>
#             <li>Iris versicolor</li>
#         </ul>
#     </li>
# </ul>
# <br>

# %%
iris = load_iris()
iris_X, iris_y = iris.data[:-1,:], iris.target[:-1]
iris_y= pd.get_dummies(iris_y).values
trainX, testX, trainY, testY = train_test_split(iris_X, iris_y, test_size=0.33, random_state=42)

# %% [markdown]
# Now we define x and y. These placeholders will hold our iris data (both the features and label matrices), and help pass them along to different parts of the algorithm. You can consider placeholders as empty shells into which we insert our data. We also need to give them shapes which correspond to the shape of our data. Later, we will insert data into these placeholders by “feeding” the placeholders the data via a “feed_dict” (Feed Dictionary).
#
# <h3>Why use Placeholders?</h3>
#
# <ol>
#     <li>This feature of TensorFlow allows us to create an algorithm which accepts data and knows something about the shape of the data without knowing the amount of data going in.</li>
#     <li>When we insert “batches” of data in training, we can easily adjust how many examples we train on in a single step without changing the entire algorithm.</li>
# </ol>

# %%
# numFeatures is the number of features in our input data.
# In the iris dataset, this number is '4'.
numFeatures = trainX.shape[1]

# numLabels is the number of classes our data points can be in.
# In the iris dataset, this number is '3'.
numLabels = trainY.shape[1]


# Placeholders
# 'None' means TensorFlow shouldn't expect a fixed number in that dimension
X = tf.placeholder(tf.float32, [None, numFeatures]) # Iris has 4 features, so X is a tensor to hold our data.
yGold = tf.placeholder(tf.float32, [None, numLabels]) # This will be our correct answers matrix for 3 classes.

# %% [markdown]
# <h3>Set model weights and bias</h3>
#
# Much like Linear Regression, we need a shared variable weight matrix for Logistic Regression. We initialize both <code>W</code> and <code>b</code> as tensors full of zeros. Since we are going to learn <code>W</code> and <code>b</code>, their initial value does not matter too much. These variables are the objects which define the structure of our regression model, and we can save them after they have been trained so we can reuse them later.
#
# We define two TensorFlow variables as our parameters. These variables will hold the weights and biases of our logistic regression and they will be continually updated during training.
#
# Notice that <code>W</code> has a shape of [4, 3] because we want to multiply the 4-dimensional input vectors by it to produce 3-dimensional vectors of evidence for the difference classes. <code>b</code> has a shape of [3] so we can add it to the output. Moreover, unlike our placeholders above which are essentially empty shells waiting to be fed data, TensorFlow variables need to be initialized with values, e.g. with zeros.

# %%
W = tf.Variable(tf.zeros([4, 3]))  # 4-dimensional input and  3 classes
b = tf.Variable(tf.zeros([3])) # 3-dimensional output [0,0,1],[0,1,0],[1,0,0]

# %%
#Randomly sample from a normal distribution with standard deviation .01

weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=0.01,
                                       name="weights"))

bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=0.01,
                                    name="bias"))

# %% [markdown]
# <h3>Logistic Regression model</h3>
#
# We now define our operations in order to properly run the Logistic Regression. Logistic regression is typically thought of as a single equation:
#
# $$
# ŷ =sigmoid(WX+b)
# $$
#
# However, for the sake of clarity, we can have it broken into its three main components:
# - a weight times features matrix multiplication operation,
# - a summation of the weighted features and a bias term,
# - and finally the application of a sigmoid function.
#
# As such, you will find these components defined as three separate operations below.

# %%
# Three-component breakdown of the Logistic Regression equation.
# Note that these feed into each other.
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias") 
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# %% [markdown]
# As we have seen before, the function we are going to use is the <i>logistic function</i> $(\frac{1}{1+e^{-Wx}})$, which is fed the input data after applying weights and bias. In TensorFlow, this function is implemented as the <code>nn.sigmoid</code> function. Effectively, this fits the weighted input with bias into a 0-100 percent curve, which is the probability function we want.

# %% [markdown]
# <hr>

# %% [markdown]
# <a id="ref3"></a>
# <h2>Training</h2>
#
# The learning algorithm is how we search for the best weight vector (${\bf w}$). This search is an optimization problem looking for the hypothesis that optimizes an error/cost measure.
#
# <b>What tell us our model is bad?</b>
# The Cost or Loss of the model, so what we want is to minimize that.
#
# <b>What is the cost function in our model?</b>
# The cost function we are going to utilize is the Squared Mean Error loss function.
#
# <b>How to minimize the cost function?</b>
# We can't use <b>least-squares linear regression</b> here, so we will use <a href="http://en.wikipedia.org/wiki/Gradient_descent">gradient descent</a> instead. Specifically, we will use batch gradient descent which calculates the gradient from all data points in the data set.
#
# <h3>Cost function</h3>
# Before defining our cost function, we need to define how long we are going to train and how should we define the learning rate.

# %%
# Number of Epochs in our training
numEpochs = 7000

# Defining our learning rate iterations (decay)
learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

# %%
#Defining our cost function - Squared Mean Error
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")

#Defining our Gradient Descent
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %% [markdown]
# Now we move on to actually running our operations. We will start with the operations involved in the prediction phase (i.e. the logistic regression itself).
#
# First, we need to initialize our weights and biases with zeros or random values via the inbuilt Initialization Op, <b>tf.initialize_all_variables()</b>. This Initialization Op will become a node in our computational graph, and when we put the graph into a session, then the Op will run and create the variables.

# %%
# Create a tensorflow session
sess = tf.Session()

# Initialize our weights and biases variables.
init_OP = tf.global_variables_initializer()

# Initialize all tensorflow variables
sess.run(init_OP)

# %% [markdown]
# We also want some additional operations to keep track of our model's efficiency over time. We can do this like so:

# %%
# argmax(activation_OP, 1) returns the label with the most probability
# argmax(yGold, 1) is the correct label
correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))

# If every false prediction is 0 and every true prediction is 1, the average returns us the accuracy
accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))

# Summary op for regression output
activation_summary_OP = tf.summary.histogram("output", activation_OP)

# Summary op for accuracy
accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)

# Summary op for cost
cost_summary_OP = tf.summary.scalar("cost", cost_OP)

# Summary ops to check how variables (W, b) are updating after each iteration
weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))

# Merge all summaries
merged = tf.summary.merge([activation_summary_OP, accuracy_summary_OP, cost_summary_OP, weightSummary, biasSummary])

# Summary writer
writer = tf.summary.FileWriter("summary_logs", sess.graph)

# %% [markdown]
# Now we can define and run the actual training loop, like this:

# %%
# Initialize reporting variables
cost = 0
diff = 1
epoch_values = []
accuracy_values = []
cost_values = []

# Training epochs
for i in range(numEpochs):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            train_accuracy, newCost = sess.run([accuracy_OP, cost_OP], feed_dict={X: trainX, yGold: trainY})
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            # Re-assign values for variables
            diff = abs(newCost - cost)
            cost = newCost

            #generate print statements
            print("step %d, training accuracy %g, cost %g, change in cost %g"%(i, train_accuracy, newCost, diff))


# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy_OP, 
                                                     feed_dict={X: testX, 
                                                                yGold: testY})))
# Out:
# step 0, training accuracy 0.333333, cost 35.0705, change in cost 35.0705
# step 10, training accuracy 0.393939, cost 30.2753, change in cost 4.79523
# step 20, training accuracy 0.646465, cost 28.3079, change in cost 1.96743
# step 30, training accuracy 0.646465, cost 26.6429, change in cost 1.66496
# step 40, training accuracy 0.646465, cost 25.2572, change in cost 1.3857
# step 50, training accuracy 0.646465, cost 24.1118, change in cost 1.14546
# step 60, training accuracy 0.646465, cost 23.1638, change in cost 0.948023
# step 70, training accuracy 0.646465, cost 22.3744, change in cost 0.789377
# step 80, training accuracy 0.646465, cost 21.7114, change in cost 0.662968
# step 90, training accuracy 0.646465, cost 21.1491, change in cost 0.562275
# step 100, training accuracy 0.656566, cost 20.6674, change in cost 0.481712
# step 110, training accuracy 0.666667, cost 20.2506, change in cost 0.416807
# step 120, training accuracy 0.666667, cost 19.8865, change in cost 0.364086
# step 130, training accuracy 0.666667, cost 19.5656, change in cost 0.320892
# step 140, training accuracy 0.666667, cost 19.2805, change in cost 0.285192
# step 150, training accuracy 0.666667, cost 19.025, change in cost 0.25543
# step 160, training accuracy 0.676768, cost 18.7946, change in cost 0.230415
# step 170, training accuracy 0.686869, cost 18.5854, change in cost 0.209217
# step 180, training accuracy 0.686869, cost 18.3943, change in cost 0.19113
# step 190, training accuracy 0.707071, cost 18.2187, change in cost 0.175579
# step 200, training accuracy 0.717172, cost 18.0566, change in cost 0.162121
# step 210, training accuracy 0.737374, cost 17.9062, change in cost 0.150404
# step 220, training accuracy 0.737374, cost 17.766, change in cost 0.140141
# step 230, training accuracy 0.747475, cost 17.6349, change in cost 0.131098
# step 240, training accuracy 0.757576, cost 17.5118, change in cost 0.123091
# step 250, training accuracy 0.767677, cost 17.3959, change in cost 0.115965
# step 260, training accuracy 0.787879, cost 17.2863, change in cost 0.109592
# step 270, training accuracy 0.787879, cost 17.1824, change in cost 0.103872
# step 280, training accuracy 0.787879, cost 17.0837, change in cost 0.0987072
# step 290, training accuracy 0.79798, cost 16.9897, change in cost 0.0940323
# step 300, training accuracy 0.79798, cost 16.8999, change in cost 0.0897846
# step 310, training accuracy 0.79798, cost 16.814, change in cost 0.0859089
# step 320, training accuracy 0.79798, cost 16.7316, change in cost 0.0823555
# step 330, training accuracy 0.79798, cost 16.6525, change in cost 0.0790997
# step 340, training accuracy 0.808081, cost 16.5764, change in cost 0.0760975
# step 350, training accuracy 0.818182, cost 16.5031, change in cost 0.0733204
# step 360, training accuracy 0.828283, cost 16.4323, change in cost 0.0707512
# step 370, training accuracy 0.838384, cost 16.364, change in cost 0.0683632
# step 380, training accuracy 0.838384, cost 16.2978, change in cost 0.0661373
# step 390, training accuracy 0.848485, cost 16.2338, change in cost 0.0640621
# step 400, training accuracy 0.848485, cost 16.1717, change in cost 0.0621166
# step 410, training accuracy 0.848485, cost 16.1114, change in cost 0.0602951
# step 420, training accuracy 0.848485, cost 16.0528, change in cost 0.0585804
# step 430, training accuracy 0.848485, cost 15.9958, change in cost 0.0569687
# step 440, training accuracy 0.868687, cost 15.9404, change in cost 0.0554466
# step 450, training accuracy 0.868687, cost 15.8864, change in cost 0.0540066
# step 460, training accuracy 0.868687, cost 15.8337, change in cost 0.0526457
# step 470, training accuracy 0.878788, cost 15.7824, change in cost 0.0513525
# step 480, training accuracy 0.878788, cost 15.7322, change in cost 0.050128
# step 490, training accuracy 0.878788, cost 15.6833, change in cost 0.0489588
# step 500, training accuracy 0.878788, cost 15.6354, change in cost 0.0478477
# step 510, training accuracy 0.878788, cost 15.5886, change in cost 0.0467854
# step 520, training accuracy 0.878788, cost 15.5429, change in cost 0.0457726
# step 530, training accuracy 0.878788, cost 15.4981, change in cost 0.0448036
# step 540, training accuracy 0.89899, cost 15.4542, change in cost 0.0438757
# step 550, training accuracy 0.89899, cost 15.4112, change in cost 0.042985
# step 560, training accuracy 0.89899, cost 15.3691, change in cost 0.0421314
# step 570, training accuracy 0.89899, cost 15.3278, change in cost 0.0413113
# step 580, training accuracy 0.909091, cost 15.2872, change in cost 0.0405226
# step 590, training accuracy 0.909091, cost 15.2475, change in cost 0.0397615
# step 600, training accuracy 0.909091, cost 15.2084, change in cost 0.0390339
# step 610, training accuracy 0.909091, cost 15.1701, change in cost 0.0383244
# step 620, training accuracy 0.909091, cost 15.1325, change in cost 0.0376472
# step 630, training accuracy 0.909091, cost 15.0955, change in cost 0.0369873
# step 640, training accuracy 0.909091, cost 15.0591, change in cost 0.0363512
# step 650, training accuracy 0.909091, cost 15.0234, change in cost 0.035738
# step 660, training accuracy 0.909091, cost 14.9883, change in cost 0.0351429
# step 670, training accuracy 0.909091, cost 14.9537, change in cost 0.0345659
# step 680, training accuracy 0.909091, cost 14.9197, change in cost 0.0340071
# step 690, training accuracy 0.909091, cost 14.8862, change in cost 0.0334663
# step 700, training accuracy 0.909091, cost 14.8533, change in cost 0.032939
# step 710, training accuracy 0.909091, cost 14.8208, change in cost 0.0324297
# step 720, training accuracy 0.909091, cost 14.7889, change in cost 0.0319338
# step 730, training accuracy 0.909091, cost 14.7575, change in cost 0.0314522
# step 740, training accuracy 0.909091, cost 14.7265, change in cost 0.030982
# step 750, training accuracy 0.909091, cost 14.696, change in cost 0.0305271
# step 760, training accuracy 0.909091, cost 14.6659, change in cost 0.0300808
# step 770, training accuracy 0.909091, cost 14.6362, change in cost 0.0296507
# step 780, training accuracy 0.909091, cost 14.607, change in cost 0.0292301
# step 790, training accuracy 0.909091, cost 14.5782, change in cost 0.0288191
# step 800, training accuracy 0.909091, cost 14.5498, change in cost 0.0284176
# step 810, training accuracy 0.909091, cost 14.5217, change in cost 0.0280285
# step 820, training accuracy 0.909091, cost 14.4941, change in cost 0.0276489
# step 830, training accuracy 0.919192, cost 14.4668, change in cost 0.0272732
# step 840, training accuracy 0.919192, cost 14.4399, change in cost 0.0269127
# step 850, training accuracy 0.919192, cost 14.4133, change in cost 0.026556
# step 860, training accuracy 0.919192, cost 14.3871, change in cost 0.0262127
# step 870, training accuracy 0.919192, cost 14.3613, change in cost 0.0258713
# step 880, training accuracy 0.919192, cost 14.3357, change in cost 0.0255404
# step 890, training accuracy 0.919192, cost 14.3105, change in cost 0.0252171
# step 900, training accuracy 0.929293, cost 14.2856, change in cost 0.0249004
# step 910, training accuracy 0.929293, cost 14.261, change in cost 0.0245895
# step 920, training accuracy 0.929293, cost 14.2367, change in cost 0.0242853
# step 930, training accuracy 0.929293, cost 14.2127, change in cost 0.0239897
# step 940, training accuracy 0.929293, cost 14.189, change in cost 0.0236988
# step 950, training accuracy 0.929293, cost 14.1656, change in cost 0.0234127
# step 960, training accuracy 0.939394, cost 14.1425, change in cost 0.0231342
# step 970, training accuracy 0.939394, cost 14.1196, change in cost 0.0228605
# step 980, training accuracy 0.939394, cost 14.097, change in cost 0.0225916
# step 990, training accuracy 0.939394, cost 14.0747, change in cost 0.0223293
# step 1000, training accuracy 0.939394, cost 14.0526, change in cost 0.0220709
# step 1010, training accuracy 0.939394, cost 14.0308, change in cost 0.0218191
# step 1020, training accuracy 0.939394, cost 14.0092, change in cost 0.0215683
# step 1030, training accuracy 0.939394, cost 13.9879, change in cost 0.021328
# step 1040, training accuracy 0.939394, cost 13.9668, change in cost 0.0210876
# step 1050, training accuracy 0.939394, cost 13.946, change in cost 0.020854
# step 1060, training accuracy 0.939394, cost 13.9254, change in cost 0.0206232
# step 1070, training accuracy 0.939394, cost 13.905, change in cost 0.0203972
# step 1080, training accuracy 0.939394, cost 13.8848, change in cost 0.020175
# step 1090, training accuracy 0.939394, cost 13.8648, change in cost 0.0199575
# step 1100, training accuracy 0.939394, cost 13.8451, change in cost 0.019743
# step 1110, training accuracy 0.939394, cost 13.8255, change in cost 0.0195332
# step 1120, training accuracy 0.939394, cost 13.8062, change in cost 0.0193262
# step 1130, training accuracy 0.939394, cost 13.7871, change in cost 0.0191221
# step 1140, training accuracy 0.939394, cost 13.7682, change in cost 0.0189238
# step 1150, training accuracy 0.939394, cost 13.7494, change in cost 0.0187254
# step 1160, training accuracy 0.939394, cost 13.7309, change in cost 0.0185337
# step 1170, training accuracy 0.939394, cost 13.7126, change in cost 0.0183449
# step 1180, training accuracy 0.939394, cost 13.6944, change in cost 0.018157
# step 1190, training accuracy 0.939394, cost 13.6764, change in cost 0.0179739
# step 1200, training accuracy 0.939394, cost 13.6586, change in cost 0.0177917
# step 1210, training accuracy 0.939394, cost 13.641, change in cost 0.0176134
# step 1220, training accuracy 0.939394, cost 13.6236, change in cost 0.0174417
# step 1230, training accuracy 0.939394, cost 13.6063, change in cost 0.0172653
# step 1240, training accuracy 0.939394, cost 13.5892, change in cost 0.0170994
# step 1250, training accuracy 0.939394, cost 13.5723, change in cost 0.0169325
# step 1260, training accuracy 0.939394, cost 13.5555, change in cost 0.0167675
# step 1270, training accuracy 0.939394, cost 13.5389, change in cost 0.0166054
# step 1280, training accuracy 0.939394, cost 13.5225, change in cost 0.016448
# step 1290, training accuracy 0.939394, cost 13.5062, change in cost 0.0162897
# step 1300, training accuracy 0.939394, cost 13.49, change in cost 0.0161362
# step 1310, training accuracy 0.939394, cost 13.4741, change in cost 0.0159826
# step 1320, training accuracy 0.939394, cost 13.4582, change in cost 0.0158348
# step 1330, training accuracy 0.939394, cost 13.4425, change in cost 0.015686
# step 1340, training accuracy 0.939394, cost 13.427, change in cost 0.015542
# step 1350, training accuracy 0.939394, cost 13.4116, change in cost 0.0153961
# step 1360, training accuracy 0.939394, cost 13.3963, change in cost 0.0152578
# step 1370, training accuracy 0.939394, cost 13.3812, change in cost 0.0151196
# step 1380, training accuracy 0.939394, cost 13.3663, change in cost 0.0149794
# step 1390, training accuracy 0.939394, cost 13.3514, change in cost 0.0148468
# step 1400, training accuracy 0.939394, cost 13.3367, change in cost 0.0147123
# step 1410, training accuracy 0.939394, cost 13.3221, change in cost 0.0145817
# step 1420, training accuracy 0.939394, cost 13.3077, change in cost 0.0144529
# step 1430, training accuracy 0.939394, cost 13.2933, change in cost 0.0143232
# step 1440, training accuracy 0.939394, cost 13.2791, change in cost 0.0141973
# step 1450, training accuracy 0.939394, cost 13.2651, change in cost 0.0140753
# step 1460, training accuracy 0.939394, cost 13.2511, change in cost 0.0139513
# step 1470, training accuracy 0.939394, cost 13.2373, change in cost 0.0138321
# step 1480, training accuracy 0.939394, cost 13.2236, change in cost 0.0137119
# step 1490, training accuracy 0.939394, cost 13.21, change in cost 0.0135946
# step 1500, training accuracy 0.939394, cost 13.1965, change in cost 0.0134792
# step 1510, training accuracy 0.939394, cost 13.1831, change in cost 0.0133638
# step 1520, training accuracy 0.939394, cost 13.1699, change in cost 0.0132513
# step 1530, training accuracy 0.939394, cost 13.1567, change in cost 0.0131407
# step 1540, training accuracy 0.939394, cost 13.1437, change in cost 0.0130281
# step 1550, training accuracy 0.939394, cost 13.1308, change in cost 0.0129223
# step 1560, training accuracy 0.939394, cost 13.118, change in cost 0.0128145
# step 1570, training accuracy 0.939394, cost 13.1053, change in cost 0.0127106
# step 1580, training accuracy 0.939394, cost 13.0927, change in cost 0.0126038
# step 1590, training accuracy 0.939394, cost 13.0802, change in cost 0.0125017
# step 1600, training accuracy 0.939394, cost 13.0678, change in cost 0.0124016
# step 1610, training accuracy 0.949495, cost 13.0555, change in cost 0.0122986
# step 1620, training accuracy 0.949495, cost 13.0433, change in cost 0.0122004
# step 1630, training accuracy 0.949495, cost 13.0312, change in cost 0.0121031
# step 1640, training accuracy 0.949495, cost 13.0191, change in cost 0.0120058
# step 1650, training accuracy 0.949495, cost 13.0072, change in cost 0.0119114
# step 1660, training accuracy 0.949495, cost 12.9954, change in cost 0.011816
# step 1670, training accuracy 0.949495, cost 12.9837, change in cost 0.0117235
# step 1680, training accuracy 0.949495, cost 12.9721, change in cost 0.011631
# step 1690, training accuracy 0.949495, cost 12.9605, change in cost 0.0115395
# step 1700, training accuracy 0.949495, cost 12.9491, change in cost 0.0114517
# step 1710, training accuracy 0.949495, cost 12.9377, change in cost 0.0113621
# step 1720, training accuracy 0.949495, cost 12.9264, change in cost 0.0112753
# step 1730, training accuracy 0.949495, cost 12.9152, change in cost 0.0111876
# step 1740, training accuracy 0.949495, cost 12.9041, change in cost 0.0111027
# step 1750, training accuracy 0.949495, cost 12.8931, change in cost 0.0110168
# step 1760, training accuracy 0.949495, cost 12.8822, change in cost 0.0109358
# step 1770, training accuracy 0.949495, cost 12.8713, change in cost 0.0108528
# step 1780, training accuracy 0.949495, cost 12.8606, change in cost 0.0107718
# step 1790, training accuracy 0.949495, cost 12.8499, change in cost 0.0106907
# step 1800, training accuracy 0.949495, cost 12.8393, change in cost 0.0106106
# step 1810, training accuracy 0.949495, cost 12.8287, change in cost 0.0105324
# step 1820, training accuracy 0.949495, cost 12.8183, change in cost 0.0104532
# step 1830, training accuracy 0.949495, cost 12.8079, change in cost 0.0103769
# step 1840, training accuracy 0.949495, cost 12.7976, change in cost 0.0103016
# step 1850, training accuracy 0.949495, cost 12.7874, change in cost 0.0102262
# step 1860, training accuracy 0.949495, cost 12.7772, change in cost 0.0101519
# step 1870, training accuracy 0.949495, cost 12.7671, change in cost 0.0100784
# step 1880, training accuracy 0.949495, cost 12.7571, change in cost 0.010005
# step 1890, training accuracy 0.949495, cost 12.7472, change in cost 0.00993443
# step 1900, training accuracy 0.949495, cost 12.7373, change in cost 0.00986099
# step 1910, training accuracy 0.949495, cost 12.7276, change in cost 0.00979424
# step 1920, training accuracy 0.949495, cost 12.7178, change in cost 0.00972271
# step 1930, training accuracy 0.949495, cost 12.7082, change in cost 0.00965309
# step 1940, training accuracy 0.949495, cost 12.6986, change in cost 0.00958729
# step 1950, training accuracy 0.949495, cost 12.6891, change in cost 0.00951958
# step 1960, training accuracy 0.949495, cost 12.6796, change in cost 0.00945282
# step 1970, training accuracy 0.949495, cost 12.6702, change in cost 0.00938702
# step 1980, training accuracy 0.949495, cost 12.6609, change in cost 0.00932121
# step 1990, training accuracy 0.949495, cost 12.6516, change in cost 0.00925732
# step 2000, training accuracy 0.949495, cost 12.6425, change in cost 0.00919437
# step 2010, training accuracy 0.949495, cost 12.6333, change in cost 0.00912952
# step 2020, training accuracy 0.949495, cost 12.6243, change in cost 0.00906849
# step 2030, training accuracy 0.949495, cost 12.6152, change in cost 0.00900745
# step 2040, training accuracy 0.949495, cost 12.6063, change in cost 0.00894642
# step 2050, training accuracy 0.949495, cost 12.5974, change in cost 0.00888634
# step 2060, training accuracy 0.949495, cost 12.5886, change in cost 0.0088253
# step 2070, training accuracy 0.949495, cost 12.5798, change in cost 0.00876617
# step 2080, training accuracy 0.949495, cost 12.5711, change in cost 0.008708
# step 2090, training accuracy 0.949495, cost 12.5625, change in cost 0.00865078
# step 2100, training accuracy 0.949495, cost 12.5539, change in cost 0.00859261
# step 2110, training accuracy 0.949495, cost 12.5453, change in cost 0.00853539
# step 2120, training accuracy 0.949495, cost 12.5369, change in cost 0.00848007
# step 2130, training accuracy 0.949495, cost 12.5284, change in cost 0.00842476
# step 2140, training accuracy 0.949495, cost 12.5201, change in cost 0.0083704
# step 2150, training accuracy 0.949495, cost 12.5117, change in cost 0.00831413
# step 2160, training accuracy 0.949495, cost 12.5035, change in cost 0.00826263
# step 2170, training accuracy 0.949495, cost 12.4953, change in cost 0.00820732
# step 2180, training accuracy 0.949495, cost 12.4871, change in cost 0.00815487
# step 2190, training accuracy 0.949495, cost 12.479, change in cost 0.00810432
# step 2200, training accuracy 0.949495, cost 12.471, change in cost 0.00804996
# step 2210, training accuracy 0.949495, cost 12.463, change in cost 0.00800037
# step 2220, training accuracy 0.949495, cost 12.455, change in cost 0.00794697
# step 2230, training accuracy 0.949495, cost 12.4471, change in cost 0.00790024
# step 2240, training accuracy 0.949495, cost 12.4393, change in cost 0.00784874
# step 2250, training accuracy 0.949495, cost 12.4315, change in cost 0.0078001
# step 2260, training accuracy 0.949495, cost 12.4237, change in cost 0.00775146
# step 2270, training accuracy 0.949495, cost 12.416, change in cost 0.00770283
# step 2280, training accuracy 0.949495, cost 12.4084, change in cost 0.00765419
# step 2290, training accuracy 0.949495, cost 12.4008, change in cost 0.00760746
# step 2300, training accuracy 0.949495, cost 12.3932, change in cost 0.00756168
# step 2310, training accuracy 0.949495, cost 12.3857, change in cost 0.007514
# step 2320, training accuracy 0.949495, cost 12.3782, change in cost 0.00746727
# step 2330, training accuracy 0.959596, cost 12.3708, change in cost 0.00742435
# step 2340, training accuracy 0.959596, cost 12.3634, change in cost 0.00737667
# step 2350, training accuracy 0.959596, cost 12.3561, change in cost 0.0073328
# step 2360, training accuracy 0.959596, cost 12.3488, change in cost 0.00728798
# step 2370, training accuracy 0.959596, cost 12.3415, change in cost 0.00724411
# step 2380, training accuracy 0.959596, cost 12.3343, change in cost 0.0072031
# step 2390, training accuracy 0.959596, cost 12.3272, change in cost 0.00715733
# step 2400, training accuracy 0.959596, cost 12.3201, change in cost 0.00711632
# step 2410, training accuracy 0.959596, cost 12.313, change in cost 0.00707245
# step 2420, training accuracy 0.959596, cost 12.306, change in cost 0.00703144
# step 2430, training accuracy 0.959596, cost 12.299, change in cost 0.00699043
# step 2440, training accuracy 0.959596, cost 12.292, change in cost 0.00694847
# step 2450, training accuracy 0.959596, cost 12.2851, change in cost 0.00690746
# step 2460, training accuracy 0.959596, cost 12.2783, change in cost 0.00686741
# step 2470, training accuracy 0.959596, cost 12.2714, change in cost 0.00682831
# step 2480, training accuracy 0.959596, cost 12.2646, change in cost 0.0067873
# step 2490, training accuracy 0.959596, cost 12.2579, change in cost 0.00675011
# step 2500, training accuracy 0.959596, cost 12.2512, change in cost 0.00670815
# step 2510, training accuracy 0.959596, cost 12.2445, change in cost 0.00667095
# step 2520, training accuracy 0.959596, cost 12.2379, change in cost 0.0066328
# step 2530, training accuracy 0.959596, cost 12.2313, change in cost 0.00659657
# step 2540, training accuracy 0.959596, cost 12.2247, change in cost 0.00655651
# step 2550, training accuracy 0.959596, cost 12.2182, change in cost 0.00652027
# step 2560, training accuracy 0.959596, cost 12.2117, change in cost 0.00648403
# step 2570, training accuracy 0.959596, cost 12.2053, change in cost 0.00644684
# step 2580, training accuracy 0.959596, cost 12.1989, change in cost 0.0064106
# step 2590, training accuracy 0.959596, cost 12.1925, change in cost 0.00637531
# step 2600, training accuracy 0.959596, cost 12.1861, change in cost 0.00634003
# step 2610, training accuracy 0.959596, cost 12.1798, change in cost 0.00630283
# step 2620, training accuracy 0.959596, cost 12.1736, change in cost 0.0062685
# step 2630, training accuracy 0.959596, cost 12.1673, change in cost 0.00623608
# step 2640, training accuracy 0.959596, cost 12.1611, change in cost 0.00619888
# step 2650, training accuracy 0.959596, cost 12.155, change in cost 0.00616646
# step 2660, training accuracy 0.959596, cost 12.1488, change in cost 0.00613213
# step 2670, training accuracy 0.959596, cost 12.1427, change in cost 0.00609875
# step 2680, training accuracy 0.959596, cost 12.1367, change in cost 0.00606537
# step 2690, training accuracy 0.959596, cost 12.1306, change in cost 0.00603294
# step 2700, training accuracy 0.959596, cost 12.1246, change in cost 0.00599861
# step 2710, training accuracy 0.959596, cost 12.1187, change in cost 0.00596809
# step 2720, training accuracy 0.959596, cost 12.1127, change in cost 0.00593472
# step 2730, training accuracy 0.959596, cost 12.1068, change in cost 0.0059042
# step 2740, training accuracy 0.959596, cost 12.101, change in cost 0.00587177
# step 2750, training accuracy 0.959596, cost 12.0951, change in cost 0.0058403
# step 2760, training accuracy 0.959596, cost 12.0893, change in cost 0.00580978
# step 2770, training accuracy 0.959596, cost 12.0835, change in cost 0.00577831
# step 2780, training accuracy 0.959596, cost 12.0778, change in cost 0.00575066
# step 2790, training accuracy 0.959596, cost 12.0721, change in cost 0.00571632
# step 2800, training accuracy 0.959596, cost 12.0664, change in cost 0.00568962
# step 2810, training accuracy 0.959596, cost 12.0607, change in cost 0.0056572
# step 2820, training accuracy 0.959596, cost 12.0551, change in cost 0.00562859
# step 2830, training accuracy 0.959596, cost 12.0495, change in cost 0.00560093
# step 2840, training accuracy 0.959596, cost 12.0439, change in cost 0.00557041
# step 2850, training accuracy 0.959596, cost 12.0384, change in cost 0.00554276
# step 2860, training accuracy 0.959596, cost 12.0329, change in cost 0.00551224
# step 2870, training accuracy 0.959596, cost 12.0274, change in cost 0.00548553
# step 2880, training accuracy 0.959596, cost 12.0219, change in cost 0.00545597
# step 2890, training accuracy 0.959596, cost 12.0165, change in cost 0.00543022
# step 2900, training accuracy 0.959596, cost 12.0111, change in cost 0.00540161
# step 2910, training accuracy 0.959596, cost 12.0057, change in cost 0.005373
# step 2920, training accuracy 0.959596, cost 12.0004, change in cost 0.00534821
# step 2930, training accuracy 0.959596, cost 11.9951, change in cost 0.0053196
# step 2940, training accuracy 0.959596, cost 11.9898, change in cost 0.00529289
# step 2950, training accuracy 0.959596, cost 11.9845, change in cost 0.00526714
# step 2960, training accuracy 0.959596, cost 11.9793, change in cost 0.00523949
# step 2970, training accuracy 0.959596, cost 11.974, change in cost 0.00521278
# step 2980, training accuracy 0.959596, cost 11.9689, change in cost 0.00518894
# step 2990, training accuracy 0.959596, cost 11.9637, change in cost 0.00516129
# step 3000, training accuracy 0.959596, cost 11.9586, change in cost 0.0051384
# step 3010, training accuracy 0.959596, cost 11.9534, change in cost 0.00511074
# step 3020, training accuracy 0.959596, cost 11.9484, change in cost 0.0050869
# step 3030, training accuracy 0.959596, cost 11.9433, change in cost 0.00506115
# step 3040, training accuracy 0.959596, cost 11.9383, change in cost 0.00503635
# step 3050, training accuracy 0.959596, cost 11.9332, change in cost 0.00501251
# step 3060, training accuracy 0.959596, cost 11.9283, change in cost 0.00498772
# step 3070, training accuracy 0.959596, cost 11.9233, change in cost 0.00496483
# step 3080, training accuracy 0.959596, cost 11.9184, change in cost 0.00493813
# step 3090, training accuracy 0.959596, cost 11.9134, change in cost 0.00491619
# step 3100, training accuracy 0.959596, cost 11.9085, change in cost 0.0048933
# step 3110, training accuracy 0.959596, cost 11.9037, change in cost 0.00486755
# step 3120, training accuracy 0.959596, cost 11.8988, change in cost 0.00484657
# step 3130, training accuracy 0.959596, cost 11.894, change in cost 0.00482178
# step 3140, training accuracy 0.959596, cost 11.8892, change in cost 0.0048008
# step 3150, training accuracy 0.959596, cost 11.8844, change in cost 0.004776
# step 3160, training accuracy 0.959596, cost 11.8797, change in cost 0.00475311
# step 3170, training accuracy 0.959596, cost 11.8749, change in cost 0.00473213
# step 3180, training accuracy 0.959596, cost 11.8702, change in cost 0.0047102
# step 3190, training accuracy 0.959596, cost 11.8656, change in cost 0.00468826
# step 3200, training accuracy 0.959596, cost 11.8609, change in cost 0.00466537
# step 3210, training accuracy 0.959596, cost 11.8562, change in cost 0.00464344
# step 3220, training accuracy 0.959596, cost 11.8516, change in cost 0.00462151
# step 3230, training accuracy 0.959596, cost 11.847, change in cost 0.00460243
# step 3240, training accuracy 0.959596, cost 11.8424, change in cost 0.00457954
# step 3250, training accuracy 0.959596, cost 11.8379, change in cost 0.00456047
# step 3260, training accuracy 0.959596, cost 11.8333, change in cost 0.00453663
# step 3270, training accuracy 0.959596, cost 11.8288, change in cost 0.00451756
# step 3280, training accuracy 0.959596, cost 11.8243, change in cost 0.00449562
# step 3290, training accuracy 0.959596, cost 11.8199, change in cost 0.00447559
# step 3300, training accuracy 0.959596, cost 11.8154, change in cost 0.00445557
# step 3310, training accuracy 0.959596, cost 11.811, change in cost 0.00443459
# step 3320, training accuracy 0.959596, cost 11.8065, change in cost 0.00441742
# step 3330, training accuracy 0.959596, cost 11.8022, change in cost 0.00439453
# step 3340, training accuracy 0.959596, cost 11.7978, change in cost 0.00437546
# step 3350, training accuracy 0.959596, cost 11.7934, change in cost 0.00435638
# step 3360, training accuracy 0.959596, cost 11.7891, change in cost 0.00433731
# step 3370, training accuracy 0.959596, cost 11.7848, change in cost 0.00431633
# step 3380, training accuracy 0.959596, cost 11.7805, change in cost 0.00429821
# step 3390, training accuracy 0.959596, cost 11.7762, change in cost 0.00427914
# step 3400, training accuracy 0.959596, cost 11.7719, change in cost 0.00426102
# step 3410, training accuracy 0.959596, cost 11.7677, change in cost 0.00424099
# step 3420, training accuracy 0.959596, cost 11.7635, change in cost 0.00422287
# step 3430, training accuracy 0.959596, cost 11.7593, change in cost 0.0042038
# step 3440, training accuracy 0.959596, cost 11.7551, change in cost 0.00418663
# step 3450, training accuracy 0.959596, cost 11.7509, change in cost 0.00416756
# step 3460, training accuracy 0.959596, cost 11.7468, change in cost 0.00414944
# step 3470, training accuracy 0.959596, cost 11.7426, change in cost 0.00413132
# step 3480, training accuracy 0.959596, cost 11.7385, change in cost 0.00411415
# step 3490, training accuracy 0.959596, cost 11.7344, change in cost 0.00409603
# step 3500, training accuracy 0.959596, cost 11.7303, change in cost 0.00407696
# step 3510, training accuracy 0.959596, cost 11.7263, change in cost 0.00406075
# step 3520, training accuracy 0.959596, cost 11.7222, change in cost 0.00404358
# step 3530, training accuracy 0.959596, cost 11.7182, change in cost 0.00402641
# step 3540, training accuracy 0.959596, cost 11.7142, change in cost 0.00400925
# step 3550, training accuracy 0.959596, cost 11.7102, change in cost 0.00399017
# step 3560, training accuracy 0.959596, cost 11.7062, change in cost 0.00397587
# step 3570, training accuracy 0.959596, cost 11.7023, change in cost 0.0039587
# step 3580, training accuracy 0.959596, cost 11.6983, change in cost 0.00394154
# step 3590, training accuracy 0.959596, cost 11.6944, change in cost 0.00392532
# step 3600, training accuracy 0.959596, cost 11.6905, change in cost 0.00390816
# step 3610, training accuracy 0.959596, cost 11.6866, change in cost 0.00389194
# step 3620, training accuracy 0.959596, cost 11.6827, change in cost 0.00387573
# step 3630, training accuracy 0.959596, cost 11.6789, change in cost 0.00386143
# step 3640, training accuracy 0.959596, cost 11.675, change in cost 0.00384235
# step 3650, training accuracy 0.959596, cost 11.6712, change in cost 0.003829
# step 3660, training accuracy 0.959596, cost 11.6674, change in cost 0.00381088
# step 3670, training accuracy 0.959596, cost 11.6636, change in cost 0.00379562
# step 3680, training accuracy 0.959596, cost 11.6598, change in cost 0.00378227
# step 3690, training accuracy 0.959596, cost 11.656, change in cost 0.00376701
# step 3700, training accuracy 0.959596, cost 11.6523, change in cost 0.00374889
# step 3710, training accuracy 0.959596, cost 11.6486, change in cost 0.00373554
# step 3720, training accuracy 0.959596, cost 11.6448, change in cost 0.00371933
# step 3730, training accuracy 0.959596, cost 11.6411, change in cost 0.00370312
# step 3740, training accuracy 0.959596, cost 11.6374, change in cost 0.00369263
# step 3750, training accuracy 0.959596, cost 11.6338, change in cost 0.0036726
# step 3760, training accuracy 0.959596, cost 11.6301, change in cost 0.00366116
# step 3770, training accuracy 0.959596, cost 11.6265, change in cost 0.00364494
# step 3780, training accuracy 0.959596, cost 11.6228, change in cost 0.00362968
# step 3790, training accuracy 0.959596, cost 11.6192, change in cost 0.00361538
# step 3800, training accuracy 0.959596, cost 11.6156, change in cost 0.00360298
# step 3810, training accuracy 0.959596, cost 11.612, change in cost 0.00358868
# step 3820, training accuracy 0.959596, cost 11.6085, change in cost 0.00357151
# step 3830, training accuracy 0.959596, cost 11.6049, change in cost 0.00356007
# step 3840, training accuracy 0.959596, cost 11.6013, change in cost 0.00354481
# step 3850, training accuracy 0.959596, cost 11.5978, change in cost 0.00353146
# step 3860, training accuracy 0.959596, cost 11.5943, change in cost 0.0035162
# step 3870, training accuracy 0.959596, cost 11.5908, change in cost 0.0035038
# step 3880, training accuracy 0.959596, cost 11.5873, change in cost 0.00348949
# step 3890, training accuracy 0.959596, cost 11.5838, change in cost 0.0034771
# step 3900, training accuracy 0.959596, cost 11.5804, change in cost 0.00346279
# step 3910, training accuracy 0.959596, cost 11.5769, change in cost 0.00344944
# step 3920, training accuracy 0.959596, cost 11.5735, change in cost 0.00343513
# step 3930, training accuracy 0.959596, cost 11.5701, change in cost 0.00342274
# step 3940, training accuracy 0.959596, cost 11.5667, change in cost 0.00341034
# step 3950, training accuracy 0.959596, cost 11.5633, change in cost 0.00339794
# step 3960, training accuracy 0.959596, cost 11.5599, change in cost 0.00338268
# step 3970, training accuracy 0.959596, cost 11.5565, change in cost 0.00337029
# step 3980, training accuracy 0.959596, cost 11.5531, change in cost 0.00335884
# step 3990, training accuracy 0.959596, cost 11.5498, change in cost 0.00334454
# step 4000, training accuracy 0.959596, cost 11.5465, change in cost 0.00333309
# step 4010, training accuracy 0.959596, cost 11.5431, change in cost 0.00332069
# step 4020, training accuracy 0.959596, cost 11.5398, change in cost 0.00330639
# step 4030, training accuracy 0.959596, cost 11.5365, change in cost 0.00329494
# step 4040, training accuracy 0.959596, cost 11.5333, change in cost 0.00328255
# step 4050, training accuracy 0.959596, cost 11.53, change in cost 0.00327015
# step 4060, training accuracy 0.959596, cost 11.5267, change in cost 0.00325871
# step 4070, training accuracy 0.959596, cost 11.5235, change in cost 0.00324535
# step 4080, training accuracy 0.959596, cost 11.5203, change in cost 0.00323486
# step 4090, training accuracy 0.959596, cost 11.517, change in cost 0.00322151
# step 4100, training accuracy 0.959596, cost 11.5138, change in cost 0.00321007
# step 4110, training accuracy 0.959596, cost 11.5106, change in cost 0.00319862
# step 4120, training accuracy 0.959596, cost 11.5074, change in cost 0.00318623
# step 4130, training accuracy 0.949495, cost 11.5043, change in cost 0.00317478
# step 4140, training accuracy 0.949495, cost 11.5011, change in cost 0.00316429
# step 4150, training accuracy 0.949495, cost 11.4979, change in cost 0.00315094
# step 4160, training accuracy 0.949495, cost 11.4948, change in cost 0.0031395
# step 4170, training accuracy 0.949495, cost 11.4917, change in cost 0.00312901
# step 4180, training accuracy 0.949495, cost 11.4886, change in cost 0.00311756
# step 4190, training accuracy 0.949495, cost 11.4855, change in cost 0.00310707
# step 4200, training accuracy 0.949495, cost 11.4824, change in cost 0.00309467
# step 4210, training accuracy 0.949495, cost 11.4793, change in cost 0.00308418
# step 4220, training accuracy 0.949495, cost 11.4762, change in cost 0.00307083
# step 4230, training accuracy 0.949495, cost 11.4731, change in cost 0.00306225
# step 4240, training accuracy 0.949495, cost 11.4701, change in cost 0.0030508
# step 4250, training accuracy 0.949495, cost 11.467, change in cost 0.00304127
# step 4260, training accuracy 0.949495, cost 11.464, change in cost 0.00302792
# step 4270, training accuracy 0.949495, cost 11.461, change in cost 0.00301838
# step 4280, training accuracy 0.949495, cost 11.458, change in cost 0.00300789
# step 4290, training accuracy 0.949495, cost 11.455, change in cost 0.00299644
# step 4300, training accuracy 0.949495, cost 11.452, change in cost 0.00298691
# step 4310, training accuracy 0.949495, cost 11.449, change in cost 0.00297737
# step 4320, training accuracy 0.949495, cost 11.4461, change in cost 0.00296497
# step 4330, training accuracy 0.949495, cost 11.4431, change in cost 0.00295448
# step 4340, training accuracy 0.949495, cost 11.4402, change in cost 0.0029459
# step 4350, training accuracy 0.949495, cost 11.4372, change in cost 0.0029335
# step 4360, training accuracy 0.949495, cost 11.4343, change in cost 0.00292397
# step 4370, training accuracy 0.949495, cost 11.4314, change in cost 0.00291443
# step 4380, training accuracy 0.949495, cost 11.4285, change in cost 0.00290394
# step 4390, training accuracy 0.949495, cost 11.4256, change in cost 0.00289536
# step 4400, training accuracy 0.949495, cost 11.4227, change in cost 0.00288391
# step 4410, training accuracy 0.949495, cost 11.4198, change in cost 0.00287533
# step 4420, training accuracy 0.949495, cost 11.417, change in cost 0.00286484
# step 4430, training accuracy 0.949495, cost 11.4141, change in cost 0.00285339
# step 4440, training accuracy 0.949495, cost 11.4113, change in cost 0.00284576
# step 4450, training accuracy 0.949495, cost 11.4084, change in cost 0.00283432
# step 4460, training accuracy 0.949495, cost 11.4056, change in cost 0.00282574
# step 4470, training accuracy 0.949495, cost 11.4028, change in cost 0.00281715
# step 4480, training accuracy 0.949495, cost 11.4, change in cost 0.00280666
# step 4490, training accuracy 0.949495, cost 11.3972, change in cost 0.00279713
# step 4500, training accuracy 0.949495, cost 11.3944, change in cost 0.00278759
# step 4510, training accuracy 0.949495, cost 11.3916, change in cost 0.00277901
# step 4520, training accuracy 0.949495, cost 11.3889, change in cost 0.00276852
# step 4530, training accuracy 0.949495, cost 11.3861, change in cost 0.00276089
# step 4540, training accuracy 0.949495, cost 11.3833, change in cost 0.00274944
# step 4550, training accuracy 0.949495, cost 11.3806, change in cost 0.00274181
# step 4560, training accuracy 0.949495, cost 11.3779, change in cost 0.00273323
# step 4570, training accuracy 0.949495, cost 11.3751, change in cost 0.00272274
# step 4580, training accuracy 0.949495, cost 11.3724, change in cost 0.00271416
# step 4590, training accuracy 0.949495, cost 11.3697, change in cost 0.00270462
# step 4600, training accuracy 0.949495, cost 11.367, change in cost 0.00269794
# step 4610, training accuracy 0.949495, cost 11.3643, change in cost 0.0026865
# step 4620, training accuracy 0.949495, cost 11.3617, change in cost 0.00268078
# step 4630, training accuracy 0.949495, cost 11.359, change in cost 0.00266838
# step 4640, training accuracy 0.949495, cost 11.3563, change in cost 0.00266266
# step 4650, training accuracy 0.949495, cost 11.3537, change in cost 0.00265312
# step 4660, training accuracy 0.949495, cost 11.351, change in cost 0.00264359
# step 4670, training accuracy 0.949495, cost 11.3484, change in cost 0.00263596
# step 4680, training accuracy 0.949495, cost 11.3458, change in cost 0.00262737
# step 4690, training accuracy 0.949495, cost 11.3432, change in cost 0.00261784
# step 4700, training accuracy 0.949495, cost 11.3405, change in cost 0.00261021
# step 4710, training accuracy 0.949495, cost 11.3379, change in cost 0.00260258
# step 4720, training accuracy 0.949495, cost 11.3353, change in cost 0.00259399
# step 4730, training accuracy 0.949495, cost 11.3328, change in cost 0.00258446
# step 4740, training accuracy 0.949495, cost 11.3302, change in cost 0.00257778
# step 4750, training accuracy 0.949495, cost 11.3276, change in cost 0.00256824
# step 4760, training accuracy 0.949495, cost 11.3251, change in cost 0.00256252
# step 4770, training accuracy 0.949495, cost 11.3225, change in cost 0.00255203
# step 4780, training accuracy 0.949495, cost 11.32, change in cost 0.00254345
# step 4790, training accuracy 0.949495, cost 11.3174, change in cost 0.00253773
# step 4800, training accuracy 0.949495, cost 11.3149, change in cost 0.00252914
# step 4810, training accuracy 0.949495, cost 11.3124, change in cost 0.00252056
# step 4820, training accuracy 0.949495, cost 11.3099, change in cost 0.00251293
# step 4830, training accuracy 0.949495, cost 11.3074, change in cost 0.0025053
# step 4840, training accuracy 0.949495, cost 11.3049, change in cost 0.00249672
# step 4850, training accuracy 0.949495, cost 11.3024, change in cost 0.00249004
# step 4860, training accuracy 0.949495, cost 11.2999, change in cost 0.00248051
# step 4870, training accuracy 0.949495, cost 11.2974, change in cost 0.00247478
# step 4880, training accuracy 0.949495, cost 11.2949, change in cost 0.00246716
# step 4890, training accuracy 0.949495, cost 11.2925, change in cost 0.00245857
# step 4900, training accuracy 0.949495, cost 11.29, change in cost 0.00245094
# step 4910, training accuracy 0.949495, cost 11.2876, change in cost 0.00244427
# step 4920, training accuracy 0.949495, cost 11.2852, change in cost 0.00243473
# step 4930, training accuracy 0.949495, cost 11.2827, change in cost 0.00242996
# step 4940, training accuracy 0.949495, cost 11.2803, change in cost 0.00242329
# step 4950, training accuracy 0.949495, cost 11.2779, change in cost 0.00241184
# step 4960, training accuracy 0.949495, cost 11.2755, change in cost 0.00240803
# step 4970, training accuracy 0.949495, cost 11.2731, change in cost 0.00239944
# step 4980, training accuracy 0.949495, cost 11.2707, change in cost 0.00239086
# step 4990, training accuracy 0.949495, cost 11.2683, change in cost 0.00238609
# step 5000, training accuracy 0.949495, cost 11.2659, change in cost 0.00237751
# step 5010, training accuracy 0.949495, cost 11.2636, change in cost 0.00237083
# step 5020, training accuracy 0.949495, cost 11.2612, change in cost 0.00236416
# step 5030, training accuracy 0.949495, cost 11.2588, change in cost 0.00235558
# step 5040, training accuracy 0.949495, cost 11.2565, change in cost 0.00234795
# step 5050, training accuracy 0.949495, cost 11.2541, change in cost 0.00234318
# step 5060, training accuracy 0.949495, cost 11.2518, change in cost 0.00233555
# step 5070, training accuracy 0.949495, cost 11.2495, change in cost 0.00232887
# step 5080, training accuracy 0.949495, cost 11.2472, change in cost 0.00232315
# step 5090, training accuracy 0.949495, cost 11.2448, change in cost 0.00231361
# step 5100, training accuracy 0.949495, cost 11.2425, change in cost 0.00230694
# step 5110, training accuracy 0.949495, cost 11.2402, change in cost 0.00230122
# step 5120, training accuracy 0.949495, cost 11.2379, change in cost 0.00229454
# step 5130, training accuracy 0.949495, cost 11.2357, change in cost 0.00228786
# step 5140, training accuracy 0.949495, cost 11.2334, change in cost 0.00228405
# step 5150, training accuracy 0.949495, cost 11.2311, change in cost 0.00227261
# step 5160, training accuracy 0.949495, cost 11.2288, change in cost 0.00226784
# step 5170, training accuracy 0.949495, cost 11.2266, change in cost 0.00226307
# step 5180, training accuracy 0.949495, cost 11.2243, change in cost 0.00225353
# step 5190, training accuracy 0.949495, cost 11.2221, change in cost 0.00224686
# step 5200, training accuracy 0.949495, cost 11.2198, change in cost 0.00224209
# step 5210, training accuracy 0.949495, cost 11.2176, change in cost 0.00223541
# step 5220, training accuracy 0.949495, cost 11.2154, change in cost 0.00222874
# step 5230, training accuracy 0.949495, cost 11.2131, change in cost 0.00222397
# step 5240, training accuracy 0.949495, cost 11.2109, change in cost 0.00221348
# step 5250, training accuracy 0.949495, cost 11.2087, change in cost 0.00221157
# step 5260, training accuracy 0.949495, cost 11.2065, change in cost 0.00220299
# step 5270, training accuracy 0.949495, cost 11.2043, change in cost 0.00219727
# step 5280, training accuracy 0.949495, cost 11.2021, change in cost 0.00219154
# step 5290, training accuracy 0.949495, cost 11.1999, change in cost 0.00218487
# step 5300, training accuracy 0.949495, cost 11.1978, change in cost 0.0021801
# step 5310, training accuracy 0.949495, cost 11.1956, change in cost 0.00217152
# step 5320, training accuracy 0.949495, cost 11.1934, change in cost 0.00216579
# step 5330, training accuracy 0.949495, cost 11.1913, change in cost 0.00216103
# step 5340, training accuracy 0.949495, cost 11.1891, change in cost 0.0021534
# step 5350, training accuracy 0.949495, cost 11.187, change in cost 0.00214958
# step 5360, training accuracy 0.949495, cost 11.1848, change in cost 0.00214195
# step 5370, training accuracy 0.949495, cost 11.1827, change in cost 0.00213718
# step 5380, training accuracy 0.949495, cost 11.1805, change in cost 0.00212955
# step 5390, training accuracy 0.949495, cost 11.1784, change in cost 0.00212479
# step 5400, training accuracy 0.949495, cost 11.1763, change in cost 0.00211906
# step 5410, training accuracy 0.949495, cost 11.1742, change in cost 0.00211239
# step 5420, training accuracy 0.949495, cost 11.1721, change in cost 0.00210571
# step 5430, training accuracy 0.949495, cost 11.17, change in cost 0.0021019
# step 5440, training accuracy 0.949495, cost 11.1679, change in cost 0.00209522
# step 5450, training accuracy 0.949495, cost 11.1658, change in cost 0.00209045
# step 5460, training accuracy 0.949495, cost 11.1637, change in cost 0.00208282
# step 5470, training accuracy 0.949495, cost 11.1616, change in cost 0.00207806
# step 5480, training accuracy 0.949495, cost 11.1596, change in cost 0.00207329
# step 5490, training accuracy 0.949495, cost 11.1575, change in cost 0.00206661
# step 5500, training accuracy 0.949495, cost 11.1554, change in cost 0.00206184
# step 5510, training accuracy 0.949495, cost 11.1534, change in cost 0.00205517
# step 5520, training accuracy 0.949495, cost 11.1513, change in cost 0.0020504
# step 5530, training accuracy 0.949495, cost 11.1493, change in cost 0.00204563
# step 5540, training accuracy 0.949495, cost 11.1472, change in cost 0.00203896
# step 5550, training accuracy 0.949495, cost 11.1452, change in cost 0.00203419
# step 5560, training accuracy 0.949495, cost 11.1432, change in cost 0.00202751
# step 5570, training accuracy 0.949495, cost 11.1412, change in cost 0.00202274
# step 5580, training accuracy 0.949495, cost 11.1391, change in cost 0.00201702
# step 5590, training accuracy 0.949495, cost 11.1371, change in cost 0.00201321
# step 5600, training accuracy 0.949495, cost 11.1351, change in cost 0.00200558
# step 5610, training accuracy 0.949495, cost 11.1331, change in cost 0.00200367
# step 5620, training accuracy 0.949495, cost 11.1311, change in cost 0.00199604
# step 5630, training accuracy 0.949495, cost 11.1291, change in cost 0.00198936
# step 5640, training accuracy 0.949495, cost 11.1271, change in cost 0.0019865
# step 5650, training accuracy 0.949495, cost 11.1252, change in cost 0.00197983
# step 5660, training accuracy 0.949495, cost 11.1232, change in cost 0.00197697
# step 5670, training accuracy 0.949495, cost 11.1212, change in cost 0.00196934
# step 5680, training accuracy 0.949495, cost 11.1193, change in cost 0.00196457
# step 5690, training accuracy 0.949495, cost 11.1173, change in cost 0.0019598
# step 5700, training accuracy 0.949495, cost 11.1153, change in cost 0.00195408
# step 5710, training accuracy 0.949495, cost 11.1134, change in cost 0.00194836
# step 5720, training accuracy 0.949495, cost 11.1114, change in cost 0.0019474
# step 5730, training accuracy 0.949495, cost 11.1095, change in cost 0.00193977
# step 5740, training accuracy 0.949495, cost 11.1076, change in cost 0.0019331
# step 5750, training accuracy 0.949495, cost 11.1056, change in cost 0.00192928
# step 5760, training accuracy 0.949495, cost 11.1037, change in cost 0.00192451
# step 5770, training accuracy 0.949495, cost 11.1018, change in cost 0.00191975
# step 5780, training accuracy 0.949495, cost 11.0999, change in cost 0.00191498
# step 5790, training accuracy 0.949495, cost 11.098, change in cost 0.00191116
# step 5800, training accuracy 0.949495, cost 11.0961, change in cost 0.00190353
# step 5810, training accuracy 0.949495, cost 11.0942, change in cost 0.00189972
# step 5820, training accuracy 0.949495, cost 11.0923, change in cost 0.00189686
# step 5830, training accuracy 0.949495, cost 11.0904, change in cost 0.00188923
# step 5840, training accuracy 0.949495, cost 11.0885, change in cost 0.00188637
# step 5850, training accuracy 0.949495, cost 11.0866, change in cost 0.00187969
# step 5860, training accuracy 0.949495, cost 11.0847, change in cost 0.00187778
# step 5870, training accuracy 0.949495, cost 11.0829, change in cost 0.00187111
# step 5880, training accuracy 0.949495, cost 11.081, change in cost 0.00186539
# step 5890, training accuracy 0.949495, cost 11.0791, change in cost 0.00186253
# step 5900, training accuracy 0.949495, cost 11.0773, change in cost 0.0018568
# step 5910, training accuracy 0.949495, cost 11.0754, change in cost 0.0018549
# step 5920, training accuracy 0.949495, cost 11.0736, change in cost 0.00184727
# step 5930, training accuracy 0.949495, cost 11.0717, change in cost 0.00184345
# step 5940, training accuracy 0.949495, cost 11.0699, change in cost 0.00183868
# step 5950, training accuracy 0.949495, cost 11.0681, change in cost 0.00183487
# step 5960, training accuracy 0.949495, cost 11.0662, change in cost 0.00182915
# step 5970, training accuracy 0.949495, cost 11.0644, change in cost 0.00182438
# step 5980, training accuracy 0.949495, cost 11.0626, change in cost 0.00182152
# step 5990, training accuracy 0.949495, cost 11.0608, change in cost 0.0018158
# step 6000, training accuracy 0.949495, cost 11.059, change in cost 0.00181198
# step 6010, training accuracy 0.949495, cost 11.0572, change in cost 0.00180721
# step 6020, training accuracy 0.949495, cost 11.0554, change in cost 0.00180435
# step 6030, training accuracy 0.949495, cost 11.0536, change in cost 0.00179768
# step 6040, training accuracy 0.949495, cost 11.0518, change in cost 0.00179386
# step 6050, training accuracy 0.949495, cost 11.05, change in cost 0.00178909
# step 6060, training accuracy 0.949495, cost 11.0482, change in cost 0.00178623
# step 6070, training accuracy 0.949495, cost 11.0464, change in cost 0.00178242
# step 6080, training accuracy 0.939394, cost 11.0446, change in cost 0.0017767
# step 6090, training accuracy 0.939394, cost 11.0429, change in cost 0.00177193
# step 6100, training accuracy 0.939394, cost 11.0411, change in cost 0.00176811
# step 6110, training accuracy 0.939394, cost 11.0393, change in cost 0.0017643
# step 6120, training accuracy 0.939394, cost 11.0376, change in cost 0.00176048
# step 6130, training accuracy 0.939394, cost 11.0358, change in cost 0.00175571
# step 6140, training accuracy 0.939394, cost 11.0341, change in cost 0.00175095
# step 6150, training accuracy 0.939394, cost 11.0323, change in cost 0.00174713
# step 6160, training accuracy 0.939394, cost 11.0306, change in cost 0.00174332
# step 6170, training accuracy 0.939394, cost 11.0288, change in cost 0.0017395
# step 6180, training accuracy 0.939394, cost 11.0271, change in cost 0.00173378
# step 6190, training accuracy 0.939394, cost 11.0254, change in cost 0.00172997
# step 6200, training accuracy 0.939394, cost 11.0236, change in cost 0.00172806
# step 6210, training accuracy 0.939394, cost 11.0219, change in cost 0.00172234
# step 6220, training accuracy 0.939394, cost 11.0202, change in cost 0.00171757
# step 6230, training accuracy 0.939394, cost 11.0185, change in cost 0.00171471
# step 6240, training accuracy 0.939394, cost 11.0168, change in cost 0.00170994
# step 6250, training accuracy 0.939394, cost 11.0151, change in cost 0.00170708
# step 6260, training accuracy 0.939394, cost 11.0134, change in cost 0.00170231
# step 6270, training accuracy 0.939394, cost 11.0117, change in cost 0.00169849
# step 6280, training accuracy 0.939394, cost 11.01, change in cost 0.00169373
# step 6290, training accuracy 0.939394, cost 11.0083, change in cost 0.00169086
# step 6300, training accuracy 0.939394, cost 11.0066, change in cost 0.00168705
# step 6310, training accuracy 0.939394, cost 11.0049, change in cost 0.00168037
# step 6320, training accuracy 0.939394, cost 11.0032, change in cost 0.00167942
# step 6330, training accuracy 0.939394, cost 11.0016, change in cost 0.00167561
# step 6340, training accuracy 0.939394, cost 10.9999, change in cost 0.00166988
# step 6350, training accuracy 0.939394, cost 10.9982, change in cost 0.00166893
# step 6360, training accuracy 0.939394, cost 10.9966, change in cost 0.00166225
# step 6370, training accuracy 0.939394, cost 10.9949, change in cost 0.00166035
# step 6380, training accuracy 0.939394, cost 10.9932, change in cost 0.00165558
# step 6390, training accuracy 0.939394, cost 10.9916, change in cost 0.00165176
# step 6400, training accuracy 0.939394, cost 10.9899, change in cost 0.00164795
# step 6410, training accuracy 0.939394, cost 10.9883, change in cost 0.00164413
# step 6420, training accuracy 0.939394, cost 10.9867, change in cost 0.00164127
# step 6430, training accuracy 0.939394, cost 10.985, change in cost 0.00163651
# step 6440, training accuracy 0.939394, cost 10.9834, change in cost 0.00163364
# step 6450, training accuracy 0.939394, cost 10.9818, change in cost 0.00162983
# step 6460, training accuracy 0.939394, cost 10.9801, change in cost 0.00162506
# step 6470, training accuracy 0.939394, cost 10.9785, change in cost 0.00162315
# step 6480, training accuracy 0.939394, cost 10.9769, change in cost 0.00161839
# step 6490, training accuracy 0.939394, cost 10.9753, change in cost 0.00161457
# step 6500, training accuracy 0.939394, cost 10.9737, change in cost 0.00161171
# step 6510, training accuracy 0.939394, cost 10.9721, change in cost 0.00160694
# step 6520, training accuracy 0.939394, cost 10.9704, change in cost 0.00160408
# step 6530, training accuracy 0.939394, cost 10.9688, change in cost 0.00160122
# step 6540, training accuracy 0.939394, cost 10.9673, change in cost 0.0015955
# step 6550, training accuracy 0.939394, cost 10.9657, change in cost 0.00159454
# step 6560, training accuracy 0.939394, cost 10.9641, change in cost 0.00158978
# step 6570, training accuracy 0.939394, cost 10.9625, change in cost 0.00158691
# step 6580, training accuracy 0.939394, cost 10.9609, change in cost 0.0015831
# step 6590, training accuracy 0.939394, cost 10.9593, change in cost 0.00157928
# step 6600, training accuracy 0.939394, cost 10.9577, change in cost 0.00157547
# step 6610, training accuracy 0.939394, cost 10.9562, change in cost 0.00157356
# step 6620, training accuracy 0.939394, cost 10.9546, change in cost 0.00156784
# step 6630, training accuracy 0.939394, cost 10.953, change in cost 0.00156593
# step 6640, training accuracy 0.939394, cost 10.9515, change in cost 0.00156212
# step 6650, training accuracy 0.939394, cost 10.9499, change in cost 0.0015583
# step 6660, training accuracy 0.939394, cost 10.9484, change in cost 0.00155544
# step 6670, training accuracy 0.939394, cost 10.9468, change in cost 0.00155258
# step 6680, training accuracy 0.939394, cost 10.9453, change in cost 0.00154877
# step 6690, training accuracy 0.939394, cost 10.9437, change in cost 0.001544
# step 6700, training accuracy 0.939394, cost 10.9422, change in cost 0.00154114
# step 6710, training accuracy 0.939394, cost 10.9406, change in cost 0.00154114
# step 6720, training accuracy 0.939394, cost 10.9391, change in cost 0.00153255
# step 6730, training accuracy 0.939394, cost 10.9376, change in cost 0.00153351
# step 6740, training accuracy 0.939394, cost 10.936, change in cost 0.00152874
# step 6750, training accuracy 0.939394, cost 10.9345, change in cost 0.00152493
# step 6760, training accuracy 0.939394, cost 10.933, change in cost 0.00152302
# step 6770, training accuracy 0.939394, cost 10.9315, change in cost 0.0015192
# step 6780, training accuracy 0.939394, cost 10.93, change in cost 0.00151539
# step 6790, training accuracy 0.939394, cost 10.9284, change in cost 0.00151157
# step 6800, training accuracy 0.939394, cost 10.9269, change in cost 0.00150967
# step 6810, training accuracy 0.939394, cost 10.9254, change in cost 0.0015049
# step 6820, training accuracy 0.939394, cost 10.9239, change in cost 0.00150394
# step 6830, training accuracy 0.939394, cost 10.9224, change in cost 0.00149822
# step 6840, training accuracy 0.939394, cost 10.9209, change in cost 0.00149918
# step 6850, training accuracy 0.939394, cost 10.9194, change in cost 0.0014925
# step 6860, training accuracy 0.939394, cost 10.9179, change in cost 0.00149059
# step 6870, training accuracy 0.939394, cost 10.9165, change in cost 0.00148678
# step 6880, training accuracy 0.939394, cost 10.915, change in cost 0.00148296
# step 6890, training accuracy 0.939394, cost 10.9135, change in cost 0.00148106
# step 6900, training accuracy 0.939394, cost 10.912, change in cost 0.0014782
# step 6910, training accuracy 0.939394, cost 10.9105, change in cost 0.00147438
# step 6920, training accuracy 0.939394, cost 10.9091, change in cost 0.00147152
# step 6930, training accuracy 0.939394, cost 10.9076, change in cost 0.00146866
# step 6940, training accuracy 0.939394, cost 10.9061, change in cost 0.0014658
# step 6950, training accuracy 0.939394, cost 10.9047, change in cost 0.00146198
# step 6960, training accuracy 0.939394, cost 10.9032, change in cost 0.00145817
# step 6970, training accuracy 0.939394, cost 10.9018, change in cost 0.00145721
# step 6980, training accuracy 0.939394, cost 10.9003, change in cost 0.0014534
# step 6990, training accuracy 0.939394, cost 10.8989, change in cost 0.00145149
# final accuracy on test set: 1.0

# %% [markdown]
# <b>Why don't we plot the cost to see how it behaves?</b>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.plot([np.mean(cost_values[i-50:i]) for i in range(len(cost_values))])
plt.show()

# %% [markdown]
# Assuming no parameters were changed, you should reach a peak accuracy of 90% at the end of training, which is commendable. Try changing the parameters such as the length of training, and maybe some operations to see how the model behaves. Does it take much longer? How is the performance?

# %% [markdown]
# <hr>

# %% [markdown]
# ## Want to learn more?
#
# Running deep learning programs usually needs a high performance platform. __PowerAI__ speeds up deep learning and AI. Built on IBM’s Power Systems, __PowerAI__ is a scalable software platform that accelerates deep learning and AI with blazing performance for individual users or enterprises. The __PowerAI__ platform supports popular machine learning libraries and dependencies including TensorFlow, Caffe, Torch, and Theano. You can use [PowerAI on IMB Cloud](https://cocl.us/ML0120EN_PAI).
#
# Also, you can use __Watson Studio__ to run these notebooks faster with bigger datasets.__Watson Studio__ is IBM’s leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, __Watson Studio__ enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of __Watson Studio__ users today with a free account at [Watson Studio](https://cocl.us/ML0120EN_DSX).This is the end of this lesson. Thank you for reading this notebook, and good luck on your studies.

# %% [markdown]
# ### Thanks for completing this lesson!
#
# This is the end of **Logistic Regression with TensorFlow** notebook. Hopefully, now you have a deeper understanding of Logistic Regression and how its structure and flow work. Thank you for reading this notebook and good luck on your studies.

# %% [markdown]
# Created by: <a href="https://br.linkedin.com/in/walter-gomes-de-amorim-junior-624726121">Saeed Aghabozorgi</a> , <a href="https://br.linkedin.com/in/walter-gomes-de-amorim-junior-624726121">Walter Gomes de Amorim Junior</a> ,  Victor Barros Costa

# %% [markdown]
# <hr>
#
# Copyright &copy; 2018 [Cognitive Class](https://cocl.us/DX0108EN_CC). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
